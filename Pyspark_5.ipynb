# %% [markdown]
# <a href="https://colab.research.google.com/github/t-abs/Apache-Spark/blob/main/Pyspark_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("ColabSparkSession").getOrCreate()

# %% [markdown]
# Reading Apache Parquet File
#
#  Apache Parquet is a free and open-source column-oriented data storage format in the Apache Hadoop ecosystem inspired by Google Dremel interactive ad-hoc query system for analysis of read-only nested data.

# %%
df=spark.read.parquet("/content/part-r-00000-1a9822ba-b8fb-4d8e-844a-ea30d0801b9e.gz.parquet")
df.show()
# Out:
# +--------------------+-------------------+-----+
# |   DEST_COUNTRY_NAME|ORIGIN_COUNTRY_NAME|count|
# +--------------------+-------------------+-----+
# |       United States|            Romania|    1|
# |       United States|            Ireland|  264|
# |       United States|              India|   69|
# |               Egypt|      United States|   24|
# |   Equatorial Guinea|      United States|    1|
# |       United States|          Singapore|   25|
# |       United States|            Grenada|   54|
# |          Costa Rica|      United States|  477|
# |             Senegal|      United States|   29|
# |       United States|   Marshall Islands|   44|
# |              Guyana|      United States|   17|
# |       United States|       Sint Maarten|   53|
# |               Malta|      United States|    1|
# |             Bolivia|      United States|   46|
# |            Anguilla|      United States|   21|
# |Turks and Caicos ...|      United States|  136|
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-536757609.py in <cell line: 0>()
#       1 df=spark.read.parquet("/content/part-r-00000-1a9822ba-b8fb-4d8e-844a-ea30d0801b9e.gz.parquet")
# ----> 2 df1.show()
#
# NameError: name 'df1' is not defined

# %% [markdown]
# Analysis Error

# %%
df1=spark.read.format("json") \
    .option("inferSchema","true") \
    .option("multiline","true") \
    .load("/content/Multilined.json")
df2.show()
df2.printSchema()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3629048310.py in <cell line: 0>()
#       3     .option("multiline","true") \
#       4     .load("/content/Multilined.json")
# ----> 5 df2.show()
#       6 df2.printSchema()
#
# NameError: name 'df2' is not defined
